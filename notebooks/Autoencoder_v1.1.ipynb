# %% [markdown]
# ## Pronóstico de series de tiempo de precipitación con autoencoder y DMD

# %%
import pandas as pd
import numpy as np

# Leer los datos desde el archivo CSV
# Supongamos que el archivo CSV tiene N filas (observaciones) y P columnas (estaciones)
data_df = pd.read_csv('../data/precipitation_test.csv')

# Convertir el DataFrame a un array de NumPy
data = data_df.values

# Verificar la forma de los datos
print(data.shape)  # Esto imprimirá (N, P), donde N es el número de observaciones y P es el número de estaciones.
# Guardar los datos en formato .npy
np.save('../data/precipitation_data.npy', data)
# Out:
# (1826, 30)

# %%
import xarray as xr
import numpy as np
from keras.models import Model
from keras.layers import Input, LSTM, RepeatVector, Dense
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from pydmd import DMD

# Parámetros del espacio latente
latent_dim = 100 # Ajustar la dimensión del espacio latente
# Out:
# 2025-10-05 05:45:44.608205: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-05 05:45:44.640705: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-05 05:45:44.640729: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-05 05:45:44.640751: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-05 05:45:44.648274: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Ruta del archivo (ya debe estar en la carpeta montada)
archivo = "../data/ERA5_daily_precipitation_1950_2022.nc"

# Abrir dataset
ds = xr.open_dataset(archivo)
ds
# Out:
# <xarray.Dataset> Size: 678MB
# Dimensions:    (time: 26663, latitude: 155, longitude: 41)
# Coordinates:
#   * longitude  (longitude) float32 164B -76.0 -75.75 -75.5 ... -66.25 -66.0
#   * latitude   (latitude) float32 620B -17.5 -17.75 -18.0 ... -55.5 -55.75 -56.0
#   * time       (time) datetime64[ns] 213kB 1950-01-01T12:00:00 ... 2022-12-31...
# Data variables:
#     tp         (time, latitude, longitude) float32 678MB ...

# %%
ds = ds.sel(time=slice("1980-01-01", "2022-12-31")) # Filtra desde 2000 a 2022
ds = ds.sel(latitude=slice(-30, -40)) # Filtra zona central
ds['tp'] = ds['tp'].where(ds['tp'] >= 0, 0) # Hace toda tp>=0
ds
# Out:
# <xarray.Dataset> Size: 106MB
# Dimensions:    (time: 15706, latitude: 41, longitude: 41)
# Coordinates:
#   * longitude  (longitude) float32 164B -76.0 -75.75 -75.5 ... -66.25 -66.0
#   * latitude   (latitude) float32 164B -30.0 -30.25 -30.5 ... -39.5 -39.75 -40.0
#   * time       (time) datetime64[ns] 126kB 1980-01-01T12:00:00 ... 2022-12-31...
# Data variables:
#     tp         (time, latitude, longitude) float32 106MB 0.2402 0.2736 ... 0.0

# %%
import numpy as np
import xarray as xr
import tensorflow as tf
from numpy.lib.stride_tricks import sliding_window_view

# =========================
# 2) Ordena coords: lon O→E, lat S→N
# =========================
if float(ds.longitude[0]) > float(ds.longitude[-1]):
    ds = ds.sortby("longitude")
# ERA5 suele traer lat N→S; queremos S→N (ascendente)
if float(ds.latitude[0]) > float(ds.latitude[-1]):
    ds = ds.sortby("latitude")

# %%
# =========================
# 3) Extrae tensor base (T, H, W, C)
# =========================
tp = ds["tp"]  # mm por paso temporal
# Asegura dtype
tp = tp.astype("float32")

# Manejo de NaNs: relleno + canal máscara (opcional)
use_mask_channel = False
if tp.isnull().any():
    use_mask_channel = True
    mask = xr.where(tp.notnull(), 1.0, 0.0).astype("float32")
    tp = tp.fillna(0.0)

# A (T,H,W)
X = tp.transpose("time", "latitude", "longitude").values  # -> (T,H,W)
T_total, H, W = X.shape

# Apila canales
channels = [X[..., None]]  # C=1
if use_mask_channel:
    M = mask.transpose("time", "latitude", "longitude").values.astype("float32")
    channels.append(M[..., None])  # C+=1
X_full = np.concatenate(channels, axis=-1).astype("float32")  # (T,H,W,C)
C = X_full.shape[-1]

print("Forma maestro:", X_full.shape)  # esperado: (8401, 41, 41, C)
# Out:
# Forma maestro: (15706, 41, 41, 1)

# %%
# =========================
# 4) Splits temporales (ajusta fechas a tu rango real)
# =========================
# Usa las fechas del dataset para que no falle si no tienes todo 2000–2022
t0 = np.datetime_as_string(ds.time.values[0], unit="D")
t1 = np.datetime_as_string(ds.time.values[-1], unit="D")
print("Rango temporal:", t0, "→", t1)
# Out:
# Rango temporal: 1980-01-01 → 2022-12-31

# %%
time_train = ["2000-01-01", "2016-12-31"]
time_val = ["2017-01-01", "2019-12-31"]
time_test = ["2020-01-01",None]

def to_array(dsi):
    arr = dsi["tp"].transpose("time", "latitude", "longitude").astype("float32")
    if use_mask_channel:
        m = xr.where(dsi["tp"].notnull(), 1.0, 0.0).transpose("time","latitude","longitude").astype("float32")
        arr = xr.concat([arr, m], dim="channel")  # (time, lat, lon, channel) pero falta expand
        arr = arr.transpose("time","latitude","longitude","channel")
        return arr.values
    else:
        return arr.values[..., None]

Xtr = to_array(ds.sel(time=slice(time_train[0], time_train[1])))
Xva = to_array(ds.sel(time=slice(time_val[0], time_val[1])))
Xte = to_array(ds.sel(time=slice(time_test[0], time_test[1])))

print("Train:", Xtr.shape, "Val:", Xva.shape, "Test:", Xte.shape)
# Out:
# Train: (6210, 41, 41, 1) Val: (1095, 41, 41, 1) Test: (1096, 41, 41, 1)

# %%
# =========================
# 5) Normalización (solo con TRAIN)
#    z-score por canal; para precip muy sesgada podrías hacer log1p antes
# =========================
# Si quieres log1p solo en canal 0 (tp), descomenta:
# Xtr[...,0] = np.log1p(Xtr[...,0])
# Xva[...,0] = np.log1p(Xva[...,0])
# Xte[...,0] = np.log1p(Xte[...,0])

# Stats por canal usando train (media/σ sobre (time, lat, lon))
mu = Xtr.reshape(-1, C).mean(axis=0)
sd = Xtr.reshape(-1, C).std(axis=0) + 1e-8

def normalize(x, mu, sd):
    return (x - mu.reshape(1,1,1,C)) / sd.reshape(1,1,1,C)

Xtr = normalize(Xtr, mu, sd).astype("float32")
Xva = normalize(Xva, mu, sd).astype("float32")
Xte = normalize(Xte, mu, sd).astype("float32")

# =========================
# 6) Ventaneo temporal (N, T, H, W, C)
# =========================
T_window = 32   # longitud de ventana
stride   = 1    # salto entre ventanas


def make_windows(X4d, T=32, S=4):
    """
    X4d: (T_total, H, W, C)  ->  (N, T, H, W, C)
    Ventaneo solo en tiempo, con stride S.
    """
    tlen = X4d.shape[0]
    if tlen < T:
        return np.empty((0, T) + X4d.shape[1:], dtype=X4d.dtype)
    starts = np.arange(0, tlen - T + 1, S, dtype=int)
    out = np.empty((len(starts), T) + X4d.shape[1:], dtype=X4d.dtype)
    for j, i in enumerate(starts):
        out[j] = X4d[i:i+T]   # (T, H, W, C)
    return out

Xtr_w = make_windows(Xtr, T_window, stride)
Xva_w = make_windows(Xva, T_window, stride)
Xte_w = make_windows(Xte, T_window, stride)

print("Windows → Train:", Xtr_w.shape, "Val:", Xva_w.shape, "Test:", Xte_w.shape)
# Ejemplo esperado con T_total~8401: (≈2093, 32, 41, 41, C)
# Out:
# Windows → Train: (6179, 32, 41, 41, 1) Val: (1064, 32, 41, 41, 1) Test: (1065, 32, 41, 41, 1)

# %%
# =========================
# 7) tf.data Datasets
# =========================
batch_size = 16
AUTOTUNE = tf.data.AUTOTUNE

def to_ds(X):
    ds = tf.data.Dataset.from_tensor_slices((X, X))  # AE: input = target
    #ds = ds.shuffle(min(len(X), 4096), reshuffle_each_iteration=True, seed=42)
    ds = ds.batch(batch_size).prefetch(AUTOTUNE)
    return ds

train_ds = to_ds(Xtr_w)
val_ds   = tf.data.Dataset.from_tensor_slices((Xva_w, Xva_w)).batch(batch_size).prefetch(AUTOTUNE)
test_ds  = tf.data.Dataset.from_tensor_slices((Xte_w, Xte_w)).batch(batch_size)
# Out:
# 2025-10-05 05:45:51.954147: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-05 05:45:51.960186: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-05 05:45:51.960222: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-05 05:45:51.962298: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-05 05:45:51.962343: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-05 05:45:51.962362: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-05 05:45:52.070638: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-05 05:45:52.070695: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-05 05:45:52.070700: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1977] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-10-05 05:45:52.070779: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-05 05:45:52.070798: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5520 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# === antes de construir el modelo ===
H, W = 41, 41          # tus dims actuales
t_factor = 2*2*2       # por si cambias strides en tiempo (aquí 8)
sp_factor = 2*2*2*2    # factor espacial total (aquí 16)

def pad_to_multiple(n, k):
    need = (-n) % k               # cuánto falta para múltiplo de k
    return need // 2, need - need // 2  # reparto (arriba/abajo)

pad_h = pad_to_multiple(H, sp_factor)   # (3,4) para 41→48
pad_w = pad_to_multiple(W, sp_factor)   # (3,4) para 41→48
print("padding H,W:", pad_h, pad_w)
# Out:
# padding H,W: (3, 4) (3, 4)

# %%
from tensorflow.keras import layers, Model

input_shape = (T_window, H, W, C)
inp = layers.Input(shape=input_shape)

# PAD al inicio → (T, 48, 48, C)
x = layers.ZeroPadding3D(padding=((0,0), pad_h, pad_w))(inp)

# Encoder
x = layers.Conv3D(16, (3,3,3), strides=(1,2,2), padding="same", activation="relu")(x)
x = layers.Conv3D(32, (3,3,3), strides=(2,2,2), padding="same", activation="relu")(x)
x = layers.Conv3D(64, (3,3,3), strides=(2,2,2), padding="same", activation="relu")(x)
z = layers.Conv3D(128,(3,3,3), strides=(2,2,2), padding="same", activation="relu")(x)

# Decoder (espejo)
x = layers.Conv3DTranspose(64, (3,3,3), strides=(2,2,2), padding="same", activation="relu")(z)
x = layers.Conv3DTranspose(32, (3,3,3), strides=(2,2,2), padding="same", activation="relu")(x)
x = layers.Conv3DTranspose(16, (3,3,3), strides=(2,2,2), padding="same", activation="relu")(x)
x = layers.Conv3DTranspose(C,  (3,3,3), strides=(1,2,2), padding="same", activation="linear")(x)

# CROP al final → (T, 41, 41, C) exactamente como tu target
out = layers.Cropping3D(cropping=((0,0), pad_h, pad_w))(x)

# --- Pinball ---
def pinball_loss(tau=0.98):
    tau = tf.constant(tau, dtype=tf.float32)
    def loss_fn(y_true, y_pred):
        e = y_true - y_pred
        return tf.reduce_mean(tf.maximum(tau*e, (tau-1.0)*e))
    return loss_fn

def tweedie_deviance_loss(power=1.6, eps=1e-6):
    """
    Implementación de la deviance de Tweedie como pérdida en Keras/TensorFlow.
    power: p en la distribución Tweedie, debe ser 1 < p < 2 para mezcla cero + continua.
    eps: valor pequeño para evitar potencias de 0 u operación no definida.
    """
    p = tf.constant(power, dtype=tf.float32)
    def loss_fn(y_true, y_pred):
        # Asegurarnos de predicciones positivas (por ejemplo con softplus o clip)
        yp = tf.maximum(y_pred, eps)
        yt = tf.maximum(y_true, 0.0)
        term1 = - yt * tf.pow(yp, 1.0 - p) / (1.0 - p)
        term2 = tf.pow(yp, 2.0 - p) / (2.0 - p)
        loss = term1 + term2
        return tf.reduce_mean(loss)
    return loss_fn

# --- Mezcla Tweedie + MSE + Pinball ---
def mixed_tweedie_mse_pinball(
    w_rmse=0.30, w_tweedie=0.40, w_pin=0.30,
    tau=0.98, power=1.5, y_in_log1p=False
):
    # Tweedie de Keras sin reducción para poder promediar nosotros:
    tweedie = tweedie_deviance_loss(power=power)
    pin = pinball_loss(tau)

    def loss_fn(y_true, y_pred):
        if y_in_log1p:
            y_true_mm = tf.expm1(y_true)
            y_pred_mm = tf.expm1(y_pred)
        else:
            y_true_mm = y_true
            y_pred_mm = y_pred

        # Componentes
        rmse = tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))
        twd = tf.reduce_mean(tweedie(y_true_mm, tf.maximum(y_pred_mm, 0.0)))  # Tweedie exige y_pred>0
        pbl = pin(y_true_mm, y_pred_mm)

        return w_rmse*rmse + w_tweedie*twd + w_pin*pbl

    return loss_fn

w_rmse=0.3
w_tweedie=0.01
w_pin=0.7
tau_ = 0.95

ae = Model(inp, out)
ae.compile(optimizer=tf.keras.optimizers.Adam(1e-3), loss=mixed_tweedie_mse_pinball(w_rmse=w_rmse, w_tweedie=w_tweedie, w_pin=w_pin, tau=tau_), metrics=[pinball_loss(tau_), 'mse', tf.keras.metrics.RootMeanSquaredError(name='rmse')])
ae.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 41, 41, 1)]   0
#
#  zero_padding3d (ZeroPaddin  (None, 32, 48, 48, 1)     0
#  g3D)
#
#  conv3d (Conv3D)             (None, 32, 24, 24, 16)    448
#
#  conv3d_1 (Conv3D)           (None, 16, 12, 12, 32)    13856
#
#  conv3d_2 (Conv3D)           (None, 8, 6, 6, 64)       55360
#
#  conv3d_3 (Conv3D)           (None, 4, 3, 3, 128)      221312
#
#  conv3d_transpose (Conv3DTr  (None, 8, 6, 6, 64)       221248
#  anspose)
#
#  conv3d_transpose_1 (Conv3D  (None, 16, 12, 12, 32)    55328
#  Transpose)
#
#  conv3d_transpose_2 (Conv3D  (None, 32, 24, 24, 16)    13840
#  Transpose)
#
#  conv3d_transpose_3 (Conv3D  (None, 32, 48, 48, 1)     433
#  Transpose)
#
#  cropping3d (Cropping3D)     (None, 32, 41, 41, 1)     0
#
# =================================================================
# Total params: 581825 (2.22 MB)
# Trainable params: 581825 (2.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# =========================
# 9) Entrenamiento
# =========================
epochs = 50
history = ae.fit(train_ds, validation_data=val_ds, epochs=epochs)
# Out:
# Epoch 1/50
# 2025-10-05 05:45:56.957150: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8600
# 2025-10-05 05:45:58.491369: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f44484ee070 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-10-05 05:45:58.491392: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Laptop GPU, Compute Capability 8.9
# 2025-10-05 05:45:58.494980: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-05 05:45:58.565311: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 387/387 [==============================] - 10s 16ms/step - loss: 0.3785 - loss_fn: 0.1513 - mse: 0.8073 - rmse: 0.8985 - val_loss: 0.2853 - val_loss_fn: 0.1019 - val_mse: 0.4738 - val_rmse: 0.6883
# Epoch 2/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.3017 - loss_fn: 0.1042 - mse: 0.5707 - rmse: 0.7554 - val_loss: 0.2591 - val_loss_fn: 0.0786 - val_mse: 0.4270 - val_rmse: 0.6534
# Epoch 3/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.2740 - loss_fn: 0.0891 - mse: 0.4717 - rmse: 0.6868 - val_loss: 0.2367 - val_loss_fn: 0.0767 - val_mse: 0.3311 - val_rmse: 0.5754
# Epoch 4/50
# 387/387 [==============================] - 8s 20ms/step - loss: 0.2676 - loss_fn: 0.0883 - mse: 0.4522 - rmse: 0.6725 - val_loss: 0.2350 - val_loss_fn: 0.0818 - val_mse: 0.3210 - val_rmse: 0.5665
# Epoch 5/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.2455 - loss_fn: 0.0805 - mse: 0.3794 - rmse: 0.6160 - val_loss: 0.2091 - val_loss_fn: 0.0604 - val_mse: 0.2804 - val_rmse: 0.5295
# Epoch 6/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.2279 - loss_fn: 0.0719 - mse: 0.3251 - rmse: 0.5702 - val_loss: 0.2047 - val_loss_fn: 0.0653 - val_mse: 0.2514 - val_rmse: 0.5014
# Epoch 7/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.2187 - loss_fn: 0.0686 - mse: 0.3014 - rmse: 0.5490 - val_loss: 0.2000 - val_loss_fn: 0.0640 - val_mse: 0.2393 - val_rmse: 0.4892
# Epoch 8/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.2072 - loss_fn: 0.0636 - mse: 0.2714 - rmse: 0.5210 - val_loss: 0.1877 - val_loss_fn: 0.0554 - val_mse: 0.2204 - val_rmse: 0.4695
# Epoch 9/50
# 387/387 [==============================] - 8s 20ms/step - loss: 0.1954 - loss_fn: 0.0587 - mse: 0.2410 - rmse: 0.4909 - val_loss: 0.1827 - val_loss_fn: 0.0577 - val_mse: 0.1990 - val_rmse: 0.4461
# Epoch 10/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1949 - loss_fn: 0.0584 - mse: 0.2396 - rmse: 0.4895 - val_loss: 0.1861 - val_loss_fn: 0.0607 - val_mse: 0.2038 - val_rmse: 0.4515
# Epoch 11/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.2033 - loss_fn: 0.0623 - mse: 0.2643 - rmse: 0.5141 - val_loss: 0.1830 - val_loss_fn: 0.0529 - val_mse: 0.2129 - val_rmse: 0.4614
# Epoch 12/50
# 387/387 [==============================] - 5s 13ms/step - loss: 0.1910 - loss_fn: 0.0569 - mse: 0.2316 - rmse: 0.4813 - val_loss: 0.1726 - val_loss_fn: 0.0446 - val_mse: 0.1993 - val_rmse: 0.4464
# Epoch 13/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1779 - loss_fn: 0.0514 - mse: 0.2005 - rmse: 0.4478 - val_loss: 0.1669 - val_loss_fn: 0.0438 - val_mse: 0.1839 - val_rmse: 0.4288
# Epoch 14/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1811 - loss_fn: 0.0525 - mse: 0.2095 - rmse: 0.4577 - val_loss: 0.1681 - val_loss_fn: 0.0450 - val_mse: 0.1851 - val_rmse: 0.4303
# Epoch 15/50
# 387/387 [==============================] - 8s 20ms/step - loss: 0.1739 - loss_fn: 0.0498 - mse: 0.1924 - rmse: 0.4386 - val_loss: 0.2079 - val_loss_fn: 0.0399 - val_mse: 0.3431 - val_rmse: 0.5858
# Epoch 16/50
# 387/387 [==============================] - 6s 14ms/step - loss: 0.1770 - loss_fn: 0.0511 - mse: 0.2019 - rmse: 0.4493 - val_loss: 0.1637 - val_loss_fn: 0.0457 - val_mse: 0.1712 - val_rmse: 0.4138
# Epoch 17/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1737 - loss_fn: 0.0497 - mse: 0.1921 - rmse: 0.4383 - val_loss: 0.1658 - val_loss_fn: 0.0448 - val_mse: 0.1790 - val_rmse: 0.4231
# Epoch 18/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1702 - loss_fn: 0.0482 - mse: 0.1853 - rmse: 0.4305 - val_loss: 0.1649 - val_loss_fn: 0.0401 - val_mse: 0.1867 - val_rmse: 0.4321
# Epoch 19/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1709 - loss_fn: 0.0486 - mse: 0.1875 - rmse: 0.4330 - val_loss: 0.1595 - val_loss_fn: 0.0474 - val_mse: 0.1550 - val_rmse: 0.3937
# Epoch 20/50
# 387/387 [==============================] - 8s 20ms/step - loss: 0.1684 - loss_fn: 0.0475 - mse: 0.1810 - rmse: 0.4254 - val_loss: 0.1607 - val_loss_fn: 0.0467 - val_mse: 0.1608 - val_rmse: 0.4010
# Epoch 21/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1642 - loss_fn: 0.0458 - mse: 0.1722 - rmse: 0.4150 - val_loss: 0.1642 - val_loss_fn: 0.0537 - val_mse: 0.1569 - val_rmse: 0.3961
# Epoch 22/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1632 - loss_fn: 0.0454 - mse: 0.1705 - rmse: 0.4129 - val_loss: 0.1569 - val_loss_fn: 0.0400 - val_mse: 0.1639 - val_rmse: 0.4048
# Epoch 23/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1605 - loss_fn: 0.0441 - mse: 0.1651 - rmse: 0.4063 - val_loss: 0.1578 - val_loss_fn: 0.0434 - val_mse: 0.1600 - val_rmse: 0.4000
# Epoch 24/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1701 - loss_fn: 0.0481 - mse: 0.1864 - rmse: 0.4317 - val_loss: 0.1574 - val_loss_fn: 0.0371 - val_mse: 0.1715 - val_rmse: 0.4141
# Epoch 25/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1579 - loss_fn: 0.0432 - mse: 0.1601 - rmse: 0.4002 - val_loss: 0.1524 - val_loss_fn: 0.0404 - val_mse: 0.1514 - val_rmse: 0.3891
# Epoch 26/50
# 387/387 [==============================] - 8s 20ms/step - loss: 0.1595 - loss_fn: 0.0440 - mse: 0.1630 - rmse: 0.4037 - val_loss: 0.1588 - val_loss_fn: 0.0482 - val_mse: 0.1534 - val_rmse: 0.3917
# Epoch 27/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1582 - loss_fn: 0.0431 - mse: 0.1601 - rmse: 0.4001 - val_loss: 0.1520 - val_loss_fn: 0.0385 - val_mse: 0.1519 - val_rmse: 0.3898
# Epoch 28/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1574 - loss_fn: 0.0431 - mse: 0.1584 - rmse: 0.3980 - val_loss: 0.1493 - val_loss_fn: 0.0401 - val_mse: 0.1434 - val_rmse: 0.3786
# Epoch 29/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1605 - loss_fn: 0.0442 - mse: 0.1650 - rmse: 0.4062 - val_loss: 0.1635 - val_loss_fn: 0.0402 - val_mse: 0.1808 - val_rmse: 0.4252
# Epoch 30/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1649 - loss_fn: 0.0457 - mse: 0.1736 - rmse: 0.4167 - val_loss: 0.1568 - val_loss_fn: 0.0467 - val_mse: 0.1502 - val_rmse: 0.3875
# Epoch 31/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1661 - loss_fn: 0.0464 - mse: 0.1764 - rmse: 0.4200 - val_loss: 0.1606 - val_loss_fn: 0.0434 - val_mse: 0.1660 - val_rmse: 0.4074
# Epoch 32/50
# 387/387 [==============================] - 8s 20ms/step - loss: 0.1589 - loss_fn: 0.0435 - mse: 0.1612 - rmse: 0.4015 - val_loss: 0.1537 - val_loss_fn: 0.0369 - val_mse: 0.1607 - val_rmse: 0.4008
# Epoch 33/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1590 - loss_fn: 0.0434 - mse: 0.1621 - rmse: 0.4026 - val_loss: 0.1609 - val_loss_fn: 0.0391 - val_mse: 0.1770 - val_rmse: 0.4207
# Epoch 34/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1573 - loss_fn: 0.0429 - mse: 0.1584 - rmse: 0.3979 - val_loss: 0.1522 - val_loss_fn: 0.0361 - val_mse: 0.1588 - val_rmse: 0.3985
# Epoch 35/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1544 - loss_fn: 0.0416 - mse: 0.1527 - rmse: 0.3908 - val_loss: 0.1524 - val_loss_fn: 0.0405 - val_mse: 0.1503 - val_rmse: 0.3877
# Epoch 36/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1545 - loss_fn: 0.0414 - mse: 0.1536 - rmse: 0.3919 - val_loss: 0.1503 - val_loss_fn: 0.0392 - val_mse: 0.1473 - val_rmse: 0.3838
# Epoch 37/50
# 387/387 [==============================] - 8s 20ms/step - loss: 0.1497 - loss_fn: 0.0396 - mse: 0.1445 - rmse: 0.3802 - val_loss: 0.1478 - val_loss_fn: 0.0392 - val_mse: 0.1394 - val_rmse: 0.3734
# Epoch 38/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1470 - loss_fn: 0.0386 - mse: 0.1392 - rmse: 0.3732 - val_loss: 0.1453 - val_loss_fn: 0.0380 - val_mse: 0.1364 - val_rmse: 0.3693
# Epoch 39/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1492 - loss_fn: 0.0394 - mse: 0.1437 - rmse: 0.3791 - val_loss: 0.1539 - val_loss_fn: 0.0406 - val_mse: 0.1540 - val_rmse: 0.3924
# Epoch 40/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1529 - loss_fn: 0.0410 - mse: 0.1508 - rmse: 0.3884 - val_loss: 0.1521 - val_loss_fn: 0.0355 - val_mse: 0.1599 - val_rmse: 0.3998
# Epoch 41/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1524 - loss_fn: 0.0408 - mse: 0.1492 - rmse: 0.3862 - val_loss: 0.1449 - val_loss_fn: 0.0352 - val_mse: 0.1413 - val_rmse: 0.3759
# Epoch 42/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1545 - loss_fn: 0.0417 - mse: 0.1535 - rmse: 0.3918 - val_loss: 0.1478 - val_loss_fn: 0.0397 - val_mse: 0.1404 - val_rmse: 0.3746
# Epoch 43/50
# 387/387 [==============================] - 8s 20ms/step - loss: 0.1512 - loss_fn: 0.0401 - mse: 0.1474 - rmse: 0.3840 - val_loss: 0.1483 - val_loss_fn: 0.0355 - val_mse: 0.1488 - val_rmse: 0.3857
# Epoch 44/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1520 - loss_fn: 0.0408 - mse: 0.1484 - rmse: 0.3852 - val_loss: 0.1488 - val_loss_fn: 0.0330 - val_mse: 0.1562 - val_rmse: 0.3952
# Epoch 45/50
# 387/387 [==============================] - 5s 13ms/step - loss: 0.1502 - loss_fn: 0.0400 - mse: 0.1454 - rmse: 0.3813 - val_loss: 0.1430 - val_loss_fn: 0.0345 - val_mse: 0.1381 - val_rmse: 0.3716
# Epoch 46/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1435 - loss_fn: 0.0371 - mse: 0.1333 - rmse: 0.3652 - val_loss: 0.1412 - val_loss_fn: 0.0331 - val_mse: 0.1363 - val_rmse: 0.3691
# Epoch 47/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1487 - loss_fn: 0.0390 - mse: 0.1434 - rmse: 0.3787 - val_loss: 0.1538 - val_loss_fn: 0.0410 - val_mse: 0.1529 - val_rmse: 0.3910
# Epoch 48/50
# 387/387 [==============================] - 8s 19ms/step - loss: 0.1507 - loss_fn: 0.0400 - mse: 0.1468 - rmse: 0.3831 - val_loss: 0.1441 - val_loss_fn: 0.0337 - val_mse: 0.1420 - val_rmse: 0.3769
# Epoch 49/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1451 - loss_fn: 0.0378 - mse: 0.1359 - rmse: 0.3687 - val_loss: 0.1470 - val_loss_fn: 0.0363 - val_mse: 0.1408 - val_rmse: 0.3752
# Epoch 50/50
# 387/387 [==============================] - 5s 14ms/step - loss: 0.1533 - loss_fn: 0.0407 - mse: 0.1528 - rmse: 0.3909 - val_loss: 0.1472 - val_loss_fn: 0.0394 - val_mse: 0.1396 - val_rmse: 0.3736

# %%
def plot_training_metrics(history):
    fig, axes = plt.subplots(3, 1, figsize=(15, 10), sharex=True)
    
    # ---- LOSS ----
    ax = axes[0]
    if 'loss' in history.history:
        ax.plot(history.history['loss'], label='Entrenamiento', linewidth=2)
    if 'val_loss' in history.history:
        ax.plot(history.history['val_loss'], label='Validación', linewidth=2, linestyle='--')
    ax.set_title('Pérdida (Loss)')
    ax.set_ylabel('Loss')
    ax.legend()
    ax.grid(True, linestyle='--', alpha=0.5)
    
    # ---- MSE ----
    ax = axes[1]
    if 'mse' in history.history:
        ax.plot(history.history['mse'], label='Entrenamiento', linewidth=2)
    if 'val_mse' in history.history:
        ax.plot(history.history['val_mse'], label='Validación', linewidth=2, linestyle='--')
    ax.set_title('Error Cuadrático Medio (MSE)')
    ax.set_ylabel('MSE')
    ax.legend()
    ax.grid(True, linestyle='--', alpha=0.5)
    
    # ---- RMSE ----
    ax = axes[2]
    if 'rmse' in history.history:
        ax.plot(history.history['rmse'], label='Entrenamiento', linewidth=2)
    if 'val_rmse' in history.history:
        ax.plot(history.history['val_rmse'], label='Validación', linewidth=2, linestyle='--')
    ax.set_title('Raíz del Error Cuadrático Medio (RMSE)')
    ax.set_xlabel('Épocas')
    ax.set_ylabel('RMSE')
    ax.legend()
    ax.grid(True, linestyle='--', alpha=0.5)
    
    plt.tight_layout()
    plt.show()


plot_training_metrics(history)

# %%
# =========================
# 10) Eval & ejemplo de uso
# =========================
test_loss = ae.evaluate(test_ds)
print("Test loss:", test_loss)
# Out:
# 67/67 [==============================] - 1s 9ms/step - loss: 0.1410 - loss_fn: 0.0365 - mse: 0.1321 - rmse: 0.3635
# Test loss: [0.14097876846790314, 0.03653247281908989, 0.13213954865932465, 0.36351004242897034]

# %%
# =========================
# 11) Guardado de artefactos
# =========================
version_ae = "v1"
ae.save(f"../models/ae_3d_era5_tp_{version_ae}.keras")
np.savez(
    f"../models/normalizacion_tp_{version_ae}.npz",
    mu=mu, sd=sd,
    w_rmse=w_rmse, w_tweedie=w_tweedie, w_pin=w_pin, tau_=tau_,
    T_window=T_window, stride=stride,
    use_mask_channel=np.array([use_mask_channel], dtype=np.int8)
)

#np.savez(
#    f"../models/normalizacion_tp_{version_ae}.npz",
#    p_min=p_min, p_max=p_max,
#    T_window=T_window, stride=stride,
#    use_mask_channel=np.array([use_mask_channel], dtype=np.int8)
#)

# %%
recons = ae.predict(Xte_w, batch_size=8)

print("Reconstrucciones:", recons.shape)  # (N_test, T, H, W, C)
# Out:
# 134/134 [==============================] - 1s 4ms/step
# Reconstrucciones: (1065, 32, 41, 41, 1)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Flatten por ventana para evaluar MSE/MAE promedio
mse = np.mean((recons - Xte_w)**2)
mae = np.mean(np.abs(recons - Xte_w))

print(f"MSE total: {mse:.6f}")
print(f"MAE total: {mae:.6f}")
# Out:
# MSE total: 0.132140
# MAE total: 0.308970

# %%
def compare_plots_error(recons, Xte_w):
    # --- Promedios temporales globales ---
    orig_mean = np.mean(Xte_w[..., 0], axis=(0, 1))   # (H, W)
    recon_mean = np.mean(recons[..., 0], axis=(0, 1)) # (H, W)
    diff_mean = orig_mean - recon_mean                # (H, W)

    fig, ax = plt.subplots(1, 3, figsize=(14, 4))
    im0 = ax[0].imshow(orig_mean, cmap='viridis')
    ax[0].set_title('Original promedio')
    plt.colorbar(im0, ax=ax[0], fraction=0.046, pad=0.04)

    im1 = ax[1].imshow(recon_mean, cmap='viridis')
    ax[1].set_title('Reconstruido promedio')
    plt.colorbar(im1, ax=ax[1], fraction=0.046, pad=0.04)

    im2 = ax[2].imshow(diff_mean, cmap='RdBu', vmin=-np.max(abs(diff_mean)), vmax=np.max(abs(diff_mean)))
    ax[2].set_title('Diferencia (Original - Reconstruido)')
    plt.colorbar(im2, ax=ax[2], fraction=0.046, pad=0.04)

    for a in ax: a.axis('off')
    plt.tight_layout()
    plt.show()

    # --- Errores espaciales promedio ---
    mse_map = np.mean((recons - Xte_w)**2, axis=(0, 1, 4))   # (H, W)
    mae_map = np.mean(np.abs(recons - Xte_w), axis=(0, 1, 4)) # (H, W)

    fig, ax = plt.subplots(1, 2, figsize=(11, 4))
    im0 = ax[0].imshow(mse_map, cmap='inferno')
    ax[0].set_title('Error MSE promedio por píxel')
    plt.colorbar(im0, ax=ax[0], fraction=0.046, pad=0.04)

    im1 = ax[1].imshow(mae_map, cmap='inferno')
    ax[1].set_title('Error MAE promedio por píxel')
    plt.colorbar(im1, ax=ax[1], fraction=0.046, pad=0.04)

    for a in ax: a.axis('off')
    plt.tight_layout()
    plt.show()

    # --- Errores temporales promedio (por ventana) ---
    mse_time = np.mean((recons - Xte_w)**2, axis=(2, 3, 4))   # (N, T)
    mae_time = np.mean(np.abs(recons - Xte_w), axis=(2, 3, 4)) # (N, T)
    mse_per_window = mse_time.mean(axis=1)
    mae_per_window = mae_time.mean(axis=1)

    # --- Energía media del campo original y reconstruido ---
    # Promedio espacial por frame → luego promedio temporal por ventana
    orig_energy = np.mean(Xte_w[..., 0], axis=(2, 3))   # (N, T)
    recon_energy = np.mean(recons[..., 0], axis=(2, 3)) # (N, T)
    orig_energy = orig_energy.mean(axis=1)              # (N,)
    recon_energy = recon_energy.mean(axis=1)            # (N,)

    # --- Evolución temporal del MSE ---
    fig, ax = plt.subplots(figsize=(10, 4))
    ax.plot(mse_per_window, color='tab:red', label='Error MSE')
    ax2 = ax.twinx()
    ax2.plot(orig_energy, color='gray', alpha=0.5, label='Original (energía media)')
    ax2.plot(recon_energy, color='black', alpha=0.6, linestyle='--', label='Reconstruido (energía media)')
    ax.set_title('Evolución temporal del error MSE promedio')
    ax.set_xlabel('Ventana temporal (orden cronológico)')
    ax.set_ylabel('MSE', color='tab:red')
    ax2.set_ylabel('Valor medio del campo', color='black')
    ax.grid(alpha=0.3)
    ax.legend(loc='upper left')
    ax2.legend(loc='upper right')
    plt.tight_layout()
    plt.show()

    # --- Evolución temporal del MAE ---
    fig, ax = plt.subplots(figsize=(10, 4))
    ax.plot(mae_per_window, color='tab:blue', label='Error MAE')
    ax2 = ax.twinx()
    ax2.plot(orig_energy, color='gray', alpha=0.5, label='Original (energía media)')
    ax2.plot(recon_energy, color='black', alpha=0.6, linestyle='--', label='Reconstruido (energía media)')
    ax.set_title('Evolución temporal del error MAE promedio')
    ax.set_xlabel('Ventana temporal (orden cronológico)')
    ax.set_ylabel('MAE', color='tab:blue')
    ax2.set_ylabel('Valor medio del campo', color='black')
    ax.grid(alpha=0.3)
    ax.legend(loc='upper left')
    ax2.legend(loc='upper right')
    plt.tight_layout()
    plt.show()

    # --- Distribución global de errores ---
    fig, ax = plt.subplots(1, 2, figsize=(10, 4))
    ax[0].hist(mse_per_window, bins=40, color='tab:red', alpha=0.7)
    ax[0].set_title('Distribución de errores MSE por ventana')
    ax[0].set_xlabel('MSE'); ax[0].set_ylabel('Frecuencia')

    ax[1].hist(mae_per_window, bins=40, color='tab:blue', alpha=0.7)
    ax[1].set_title('Distribución de errores MAE por ventana')
    ax[1].set_xlabel('MAE'); ax[1].set_ylabel('Frecuencia')

    plt.tight_layout()
    plt.show()

# %%
compare_plots_error(recons*sd + mu, Xte_w*sd + mu)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Valor medio vs error (por frame)
orig_vals = np.mean(Xte_w[..., 0], axis=(2, 3))   # (N, T)
err_vals  = np.mean(np.abs(recons - Xte_w), axis=(2, 3, 4)) # (N, T)

plt.figure(figsize=(6,5))
plt.scatter(orig_vals.flatten(), err_vals.flatten(), s=2, alpha=0.3)
plt.xlabel("Precipitación media (mm)")
plt.ylabel("Error MAE")
plt.title("Error vs. intensidad de precipitación")
plt.grid(alpha=0.3)
plt.show()
